# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np

# %%
zip_path = tf.keras.utils.get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname='jena_climate_2009_2016.csv.zip',
    extract=True)
csv_path, _ = os.path.splitext(zip_path)

# %%
df = pd.read_csv(csv_path)
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
df = df[5::6]
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 5       01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78
# 11      01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77
# 17      01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66
# 23      01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02
# 29      01.01.2009 05:00:00    997.46     -9.63    263.72       -10.65
# ...                     ...       ...       ...       ...          ...
# 420521  31.12.2016 19:10:00   1002.18     -0.98    272.01        -5.36
# 420527  31.12.2016 20:10:00   1001.40     -1.40    271.66        -6.84
# 420533  31.12.2016 21:10:00   1001.19     -2.75    270.32        -6.90
# 420539  31.12.2016 22:10:00   1000.65     -2.89    270.22        -7.15
# 420545  31.12.2016 23:10:00   1000.11     -3.93    269.23        -8.09
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
df.index = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S')
df[:26]
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 01:00:00  01.01.2009 01:00:00    996.50     -8.05    265.38
# 2009-01-01 02:00:00  01.01.2009 02:00:00    996.62     -8.88    264.54
# 2009-01-01 03:00:00  01.01.2009 03:00:00    996.84     -8.81    264.59
# 2009-01-01 04:00:00  01.01.2009 04:00:00    996.99     -9.05    264.34
# 2009-01-01 05:00:00  01.01.2009 05:00:00    997.46     -9.63    263.72
# 2009-01-01 06:00:00  01.01.2009 06:00:00    997.71     -9.67    263.66
# 2009-01-01 07:00:00  01.01.2009 07:00:00    998.33     -9.17    264.12
# 2009-01-01 08:00:00  01.01.2009 08:00:00    999.17     -8.10    265.12
# 2009-01-01 09:00:00  01.01.2009 09:00:00    999.69     -7.66    265.52
# 2009-01-01 10:00:00  01.01.2009 10:00:00   1000.27     -7.04    266.10
# 2009-01-01 11:00:00  01.01.2009 11:00:00   1000.87     -7.41    265.68
# 2009-01-01 12:00:00  01.01.2009 12:00:00   1000.30     -6.87    266.27
# ...

# %%
temp = df['T (degC)']
temp.plot()
# Out:
# <AxesSubplot:xlabel='Date Time'>

# %%
# [[[1],[2],[3],[4],[5]] [6]
# [[[2],[3],[4],[5],[6]] [7]
# [[[3],[4],[5],[6],[7]] [8]
# This is going to be the big output

# window size is the number of last measurements 
def df_to_X_y(df, window_size=5):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np)-window_size):
        row = [[a] for a in df_as_np[i:i+5]]
        X.append(row)
        label = df_as_np[i+5]
        y.append(label)
    return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X, y = df_to_X_y(temp, WINDOW_SIZE)
X.shape, y.shape
# Out:
# ((70086, 5, 1), (70086,))

# %%
#Now let's split the data and put some in the test set

X_train, y_train = X[:60000], y[:60000]
X_val, y_val = X[60000:65000], y[60000:65000]
X_test, y_test = X[65000:], y[65000:]

X_train.shape, y_train.shape, X_val.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 5, 1), (60000,), (5000, 5, 1), (5086, 5, 1), (5086,))

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam


model1 = Sequential()
model1.add(InputLayer((5,1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_3 (LSTM)               (None, 64)                16896
#
#  dense_6 (Dense)             (None, 8)                 520
#
#  dense_7 (Dense)             (None, 1)                 9
#
# ...
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('model1/', save_best_only=True)
#learning rate is how fast the model is going to ifnd the smallest loss
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, callbacks=[cp])
# Out:
# Epoch 1/10
# 1873/1875 [============================>.] - ETA: 0s - loss: 34.0921 - root_mean_squared_error: 5.8388
# WARNING:absl:Found untraced functions such as lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x000001B92F6B1070> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 15s 7ms/step - loss: 34.0579 - root_mean_squared_error: 5.8359 - val_loss: 1.2285 - val_root_mean_squared_error: 1.1084
# Epoch 2/10
# ...

# %%
# Now we load the model which had the lowest validation loss
from tensorflow.keras.models import load_model

model1 = load_model('model1/')

# %%
train_predictions = model1.predict(X_train).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train} )
train_results
# Out:
# 1875/1875 [==============================] - 4s 2ms/step
#        Train Predictions  Actuals
# 0              -9.849174    -9.67
# 1              -9.672803    -9.17
# 2              -8.818568    -8.10
# 3              -7.282903    -7.66
# 4              -7.252967    -7.04
# ...                  ...      ...
# 59995           6.089974     6.07
# 59996           7.168757     9.88
# 59997          12.027665    13.53
# 59998          15.701203    15.43
# 59999          16.223997    15.54
#
# [60000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(train_results['Train Predictions'][50:100])
plt.plot(train_results['Actuals'][50:100])

# %%
test_predictions = model1.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test} )

plt.plot(test_results['Test Predictions'][:100])
plt.plot(test_results['Actuals'][:100])
# Out:
# 159/159 [==============================] - 1s 3ms/step

# %%
# Part 2

# %% [markdown]
# Let's use more variable in order to predict
# Let's automate the predictions first

# %%
from sklearn.metrics import mean_squared_error as mse

def plot_predictions1(model, X, y, start=0, end=100):
    predictions = model.predict(X).flatten()
    df = pd.DataFrame(data={'Predictions':predictions, 'Actuals':y})
    plt.plot(df['Predictions'][start:end])
    plt.plot(df['Actuals'][start:end])
    return df, mse(y, predictions)

# %%
plot_predictions1( model1 ,X_test, y_test)
# Out:
# 159/159 [==============================] - 0s 3ms/step
# (      Predictions  Actuals
#  0       14.386403    13.99
#  1       13.218189    13.46
#  2       12.855806    12.93
#  3       12.469481    12.43
#  4       12.032508    12.17
#  ...           ...      ...
#  5081    -1.149846    -0.98
#  5082    -1.434058    -1.40
#  5083    -1.597586    -2.75
#  5084    -3.391811    -2.89
#  5085    -3.164460    -3.93
#
#  [5086 rows x 2 columns],
#  0.6393483926226218)

# %%
model2 = Sequential()
model2.add(InputLayer((5, 1)))
model2.add(Conv1D(64, kernel_size=2))
model2.add(Flatten())
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))

model2.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_1 (Conv1D)           (None, 4, 64)             192
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense_10 (Dense)            (None, 8)                 2056
#
#  dense_11 (Dense)            (None, 1)                 9
#
# ...
# Total params: 2,257
# Trainable params: 2,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp2 = ModelCheckpoint('model2/', save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model2.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, callbacks=[cp2])
# Out:
# Epoch 1/10
# 1850/1875 [============================>.] - ETA: 0s - loss: 6.8765 - root_mean_squared_error: 2.6223
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 4s 2ms/step - loss: 6.8026 - root_mean_squared_error: 2.6082 - val_loss: 0.8839 - val_root_mean_squared_error: 0.9402
# Epoch 2/10
# 1858/1875 [============================>.] - ETA: 0s - loss: 0.9776 - root_mean_squared_error: 0.9888
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# ...

# %%
model3 = Sequential()
model3.add(InputLayer((5, 1)))
model3.add(GRU(64))
model3.add(Flatten())
model3.add(Dense(8, 'relu'))
model3.add(Dense(1, 'linear'))

model3.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  gru (GRU)                   (None, 64)                12864
#
#  flatten_1 (Flatten)         (None, 64)                0
#
#  dense_12 (Dense)            (None, 8)                 520
#
#  dense_13 (Dense)            (None, 1)                 9
#
# ...
# Total params: 13,393
# Trainable params: 13,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp3 = ModelCheckpoint('model3/', save_best_only=True)
model3.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model2.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, callbacks=[cp3])
# Out:
# Epoch 1/10
# 1841/1875 [============================>.] - ETA: 0s - loss: 0.6583 - root_mean_squared_error: 0.8114
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6593 - root_mean_squared_error: 0.8120 - val_loss: 0.5054 - val_root_mean_squared_error: 0.7109
# Epoch 2/10
# 1867/1875 [============================>.] - ETA: 0s - loss: 0.6597 - root_mean_squared_error: 0.8122
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# ...

# %%
temp_df = pd.DataFrame({'Temperature': temp})
temp_df['Seconds'] = temp_df.index.map(pd.Timestamp.timestamp)
temp_df
# Out:
#                      Temperature       Seconds
# Date Time
# 2009-01-01 01:00:00        -8.05  1.230772e+09
# 2009-01-01 02:00:00        -8.88  1.230775e+09
# 2009-01-01 03:00:00        -8.81  1.230779e+09
# 2009-01-01 04:00:00        -9.05  1.230782e+09
# 2009-01-01 05:00:00        -9.63  1.230786e+09
# ...                          ...           ...
# 2016-12-31 19:10:00        -0.98  1.483211e+09
# 2016-12-31 20:10:00        -1.40  1.483215e+09
# 2016-12-31 21:10:00        -2.75  1.483219e+09
# 2016-12-31 22:10:00        -2.89  1.483222e+09
# 2016-12-31 23:10:00        -3.93  1.483226e+09
#
# [70091 rows x 2 columns]

# %%
day = 60*60*24
year = 365.2425*day #Number of seconds in a day and a year

temp_df['Day sin'] = np.sin(temp_df['Seconds'] * (2* np.pi /day))
temp_df['Day cos'] = np.cos(temp_df['Seconds'] * (2* np.pi /day))
temp_df['Year sin'] = np.sin(temp_df['Seconds'] * (2* np.pi /year))
temp_df['Year cos'] = np.cos(temp_df['Seconds'] * (2* np.pi /year))

# %%
temp_df = temp_df.drop('Seconds', axis=1)
temp_df.head()
# Out:
#                      Temperature       Seconds   Day sin       Day cos  \
# Date Time
# 2009-01-04 04:00:00        -1.88  1.231042e+09  0.866025  5.000000e-01
# 2009-01-04 05:00:00        -1.64  1.231045e+09  0.965926  2.588190e-01
# 2009-01-04 06:00:00        -1.44  1.231049e+09  1.000000  5.996254e-12
# 2009-01-04 07:00:00        -1.09  1.231052e+09  0.965926 -2.588190e-01
# 2009-01-04 08:00:00        -0.89  1.231056e+09  0.866025 -5.000000e-01
# ...                          ...           ...       ...           ...
# 2009-01-07 02:00:00       -20.99  1.231294e+09  0.500000  8.660254e-01
# 2009-01-07 03:00:00       -22.76  1.231297e+09  0.707107  7.071068e-01
# 2009-01-07 04:00:00       -22.39  1.231301e+09  0.866025  5.000000e-01
# 2009-01-07 05:00:00       -22.42  1.231304e+09  0.965926  2.588190e-01
# 2009-01-07 06:00:00       -22.13  1.231308e+09  1.000000  7.652554e-12
#
#                      Year sin  Year cos
# Date Time
# 2009-01-04 04:00:00  0.063765  0.997965
# ...
